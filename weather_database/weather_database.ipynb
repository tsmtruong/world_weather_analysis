# %%
# import dependencies

import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

# %%
# create a set of 2000 random latitudes and longitudes

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)

lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats, lngs)

lat_lngs

# %%
# put coordinates in a list

coordinates = list(lat_lngs)

# %%
# import citipy

from citipy import citipy

# %%
# identify the nearest city using the citipy module 

cities = []


for coordinate in coordinates:
    
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    
    if city not in cities:
        
        cities.append(city)
        
len(cities)
# Out:
# 762

# %%
# import dependencies and keys

import requests

from config import weather_api_key

import time

from datetime import datetime

# %%
# perfrom api call

url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %%
# create an empty list to hold the weather data

city_data = []

# print the beginning of the logging

print('Beginning Data Retrival          ')

print('---------------------------------')


# create counters.

record_count = 1

set_count = 1


# loop through all the cities in the list

for i, city in enumerate(cities):
    
    
    # group cities in sets of 50 for logging purposes
    
    if (i % 50 == 0 and i >= 50):
        
        set_count +=1
        
        record_count = 1
        
        time.sleep(30)
        
        
    # create endpoint url with each city
    
    city_url = url + '&q=' + city.replace(' ', '+')
    
    
    # log the url, record, and set numbers and the city 
    
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    
    # add 1 to the record count
    
    record_count += 1
    

# run an API request for each of the cities

    try:
        
        # parse the json and retrive data
        city_weather = requests.get(city_url).json()
        
        # parse out the needed data
        city_country = city_weather['sys']['country']
        
        city_lat = city_weather['coord']['lat']
        
        city_lng = city_weather['coord']['lon']
        
        city_max_temp = city_weather['main']['temp_max']
        
        city_humidity = city_weather['main']['humidity']
        
        city_clouds = city_weather['clouds']['all']
        
        city_wind = city_weather['wind']['speed']
        
        city_description = city_weather['weather'][0]['description']
        
        
        
        
        
        # append the city information into city_data list
        
        city_data.append({'City': city.title(),
                          
                          'Country': city_country,
                         
                          'Lat': city_lat,
                         
                          'Lng': city_lng,
                         
                         'Max Temp': city_max_temp,
                         
                         'Humidity': city_humidity,
                         
                         'Cloudiness': city_clouds,
                         
                         'Wind Speed': city_wind,
                         
                         "Current Description": city_description})
        
# if an error is experienced, skip the city

    except:
        
        print('City not found. Skipping...')
        
        pass
    
    
# indicate the data loading is complete

print('----------------------------')

print('Data Retrieval Complete     ')

print('----------------------------')
# Out:
# Beginning Data Retrival
# ---------------------------------
# Processing Record 1 of Set 1 | merauke
# Processing Record 2 of Set 1 | muscat
# Processing Record 3 of Set 1 | dalvik
# Processing Record 4 of Set 1 | hilo
# Processing Record 5 of Set 1 | hajipur
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | sapa
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | lebu
# Processing Record 10 of Set 1 | port blair
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | ngukurr
# City not found. Skipping...
# Processing Record 13 of Set 1 | isiolo
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | chuy
# Processing Record 16 of Set 1 | torbay
# Processing Record 17 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 18 of Set 1 | talnakh
# Processing Record 19 of Set 1 | ponta do sol
# Processing Record 20 of Set 1 | hidrolandia
# Processing Record 21 of Set 1 | hasaki
# Processing Record 22 of Set 1 | sorong
# Processing Record 23 of Set 1 | fortuna
# Processing Record 24 of Set 1 | wattegama
# Processing Record 25 of Set 1 | maumere
# Processing Record 26 of Set 1 | wamba
# Processing Record 27 of Set 1 | acapulco
# Processing Record 28 of Set 1 | barrow
# Processing Record 29 of Set 1 | port alfred
# Processing Record 30 of Set 1 | rangoon
# Processing Record 31 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 1 | pisco
# Processing Record 33 of Set 1 | carnarvon
# Processing Record 34 of Set 1 | panzhihua
# Processing Record 35 of Set 1 | kandi
# Processing Record 36 of Set 1 | elko
# Processing Record 37 of Set 1 | san francisco
# Processing Record 38 of Set 1 | pangoa
# Processing Record 39 of Set 1 | tiksi
# Processing Record 40 of Set 1 | georgetown
# Processing Record 41 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 1 | bredasdorp
# Processing Record 43 of Set 1 | denpasar
# Processing Record 44 of Set 1 | castro
# Processing Record 45 of Set 1 | cape town
# Processing Record 46 of Set 1 | los llanos de aridane
# Processing Record 47 of Set 1 | haines junction
# Processing Record 48 of Set 1 | bluff
# Processing Record 49 of Set 1 | mataura
# Processing Record 50 of Set 1 | eydhafushi
# Processing Record 1 of Set 2 | kununurra
# Processing Record 2 of Set 2 | bilibino
# Processing Record 3 of Set 2 | san quintin
# Processing Record 4 of Set 2 | upernavik
# Processing Record 5 of Set 2 | busselton
# Processing Record 6 of Set 2 | avarua
# Processing Record 7 of Set 2 | ushuaia
# Processing Record 8 of Set 2 | airai
# Processing Record 9 of Set 2 | gurgan
# City not found. Skipping...
# Processing Record 10 of Set 2 | gardan diwal
# City not found. Skipping...
# Processing Record 11 of Set 2 | kapaa
# Processing Record 12 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 2 | vestmannaeyjar
# Processing Record 14 of Set 2 | nimaparha
# Processing Record 15 of Set 2 | albany
# Processing Record 16 of Set 2 | tuktoyaktuk
# Processing Record 17 of Set 2 | yellowknife
# Processing Record 18 of Set 2 | lulea
# Processing Record 19 of Set 2 | olinda
# Processing Record 20 of Set 2 | faya
# Processing Record 21 of Set 2 | kangaatsiaq
# Processing Record 22 of Set 2 | punta arenas
# Processing Record 23 of Set 2 | husavik
# Processing Record 24 of Set 2 | bethel
# Processing Record 25 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 2 | byron bay
# Processing Record 27 of Set 2 | khatanga
# Processing Record 28 of Set 2 | yar-sale
# Processing Record 29 of Set 2 | albion
# Processing Record 30 of Set 2 | awjilah
# Processing Record 31 of Set 2 | saint-philippe
# Processing Record 32 of Set 2 | manzanillo
# Processing Record 33 of Set 2 | mar del plata
# Processing Record 34 of Set 2 | mahebourg
# Processing Record 35 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 2 | alofi
# Processing Record 37 of Set 2 | mount gambier
# Processing Record 38 of Set 2 | hermanus
# Processing Record 39 of Set 2 | zhigansk
# Processing Record 40 of Set 2 | zhanaozen
# Processing Record 41 of Set 2 | kodiak
# Processing Record 42 of Set 2 | hamilton
# Processing Record 43 of Set 2 | frankfort
# Processing Record 44 of Set 2 | orsha
# Processing Record 45 of Set 2 | shelburne
# Processing Record 46 of Set 2 | mana
# Processing Record 47 of Set 2 | cabinda
# Processing Record 48 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 2 | codrington
# Processing Record 50 of Set 2 | bireun
# Processing Record 1 of Set 3 | selishche
# Processing Record 2 of Set 3 | paramonga
# Processing Record 3 of Set 3 | cacapava
# Processing Record 4 of Set 3 | sulphur springs
# Processing Record 5 of Set 3 | constitucion
# Processing Record 6 of Set 3 | vaitape
# Processing Record 7 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 3 | katsuura
# Processing Record 9 of Set 3 | east london
# Processing Record 10 of Set 3 | hithadhoo
# Processing Record 11 of Set 3 | tokur
# Processing Record 12 of Set 3 | puerto pinasco
# City not found. Skipping...
# Processing Record 13 of Set 3 | loa janan
# Processing Record 14 of Set 3 | tasiilaq
# Processing Record 15 of Set 3 | saint-augustin
# Processing Record 16 of Set 3 | norman wells
# Processing Record 17 of Set 3 | limbang
# Processing Record 18 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 3 | luganville
# Processing Record 20 of Set 3 | udachnyy
# Processing Record 21 of Set 3 | arraial do cabo
# Processing Record 22 of Set 3 | butaritari
# Processing Record 23 of Set 3 | chokurdakh
# Processing Record 24 of Set 3 | qaanaaq
# Processing Record 25 of Set 3 | makhu
# Processing Record 26 of Set 3 | lagoa
# Processing Record 27 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 3 | lakeside
# Processing Record 29 of Set 3 | bengkulu
# Processing Record 30 of Set 3 | avera
# Processing Record 31 of Set 3 | longyearbyen
# Processing Record 32 of Set 3 | kuybyshevskiy zaton
# Processing Record 33 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 3 | kahului
# Processing Record 35 of Set 3 | villa bruzual
# Processing Record 36 of Set 3 | hirson
# Processing Record 37 of Set 3 | ribeira grande
# Processing Record 38 of Set 3 | chilca
# Processing Record 39 of Set 3 | lima
# Processing Record 40 of Set 3 | benguela
# Processing Record 41 of Set 3 | coruripe
# Processing Record 42 of Set 3 | iqaluit
# Processing Record 43 of Set 3 | sinkat
# City not found. Skipping...
# Processing Record 44 of Set 3 | kita
# Processing Record 45 of Set 3 | san patricio
# Processing Record 46 of Set 3 | taoudenni
# Processing Record 47 of Set 3 | gasa
# Processing Record 48 of Set 3 | nawabganj
# Processing Record 49 of Set 3 | georgiyevka
# Processing Record 50 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 4 | matelandia
# Processing Record 2 of Set 4 | semirom
# Processing Record 3 of Set 4 | selikhino
# Processing Record 4 of Set 4 | palmer
# Processing Record 5 of Set 4 | new norfolk
# Processing Record 6 of Set 4 | nome
# Processing Record 7 of Set 4 | slave lake
# Processing Record 8 of Set 4 | zonhoven
# Processing Record 9 of Set 4 | tulsipur
# Processing Record 10 of Set 4 | aliwal north
# Processing Record 11 of Set 4 | ostrovnoy
# Processing Record 12 of Set 4 | ozinki
# Processing Record 13 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 14 of Set 4 | achinsk
# Processing Record 15 of Set 4 | shache
# Processing Record 16 of Set 4 | abha
# Processing Record 17 of Set 4 | makokou
# Processing Record 18 of Set 4 | nanortalik
# Processing Record 19 of Set 4 | adrar
# Processing Record 20 of Set 4 | anadyr
# Processing Record 21 of Set 4 | cabo san lucas
# Processing Record 22 of Set 4 | provideniya
# Processing Record 23 of Set 4 | encheng
# Processing Record 24 of Set 4 | vila franca do campo
# Processing Record 25 of Set 4 | namatanai
# Processing Record 26 of Set 4 | mattru
# Processing Record 27 of Set 4 | winsum
# Processing Record 28 of Set 4 | azimur
# City not found. Skipping...
# Processing Record 29 of Set 4 | sabang
# Processing Record 30 of Set 4 | jamestown
# Processing Record 31 of Set 4 | barranca
# Processing Record 32 of Set 4 | vanimo
# Processing Record 33 of Set 4 | anshan
# Processing Record 34 of Set 4 | kaitangata
# Processing Record 35 of Set 4 | popondetta
# Processing Record 36 of Set 4 | meshcherino
# Processing Record 37 of Set 4 | itarema
# Processing Record 38 of Set 4 | brownfield
# Processing Record 39 of Set 4 | saskylakh
# Processing Record 40 of Set 4 | zlynka
# Processing Record 41 of Set 4 | santa cruz
# Processing Record 42 of Set 4 | maniitsoq
# Processing Record 43 of Set 4 | kloulklubed
# Processing Record 44 of Set 4 | hofn
# Processing Record 45 of Set 4 | ulladulla
# Processing Record 46 of Set 4 | kenai
# Processing Record 47 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 4 | kharp
# Processing Record 49 of Set 4 | sabha
# Processing Record 50 of Set 4 | pandan
# Processing Record 1 of Set 5 | weiser
# Processing Record 2 of Set 5 | balkanabat
# Processing Record 3 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 4 of Set 5 | oussouye
# Processing Record 5 of Set 5 | joniskelis
# Processing Record 6 of Set 5 | talara
# Processing Record 7 of Set 5 | ji-parana
# City not found. Skipping...
# Processing Record 8 of Set 5 | gat
# Processing Record 9 of Set 5 | half moon bay
# Processing Record 10 of Set 5 | boke
# Processing Record 11 of Set 5 | fairbanks
# Processing Record 12 of Set 5 | biltine
# Processing Record 13 of Set 5 | saint george
# Processing Record 14 of Set 5 | dikson
# Processing Record 15 of Set 5 | roald
# Processing Record 16 of Set 5 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 17 of Set 5 | pahrump
# Processing Record 18 of Set 5 | khorixas
# Processing Record 19 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 5 | asfi
# Processing Record 22 of Set 5 | geraldton
# Processing Record 23 of Set 5 | kedrovyy
# Processing Record 24 of Set 5 | victoria
# Processing Record 25 of Set 5 | esperance
# Processing Record 26 of Set 5 | esqueda
# Processing Record 27 of Set 5 | lavrentiya
# Processing Record 28 of Set 5 | bambous virieux
# Processing Record 29 of Set 5 | vaini
# Processing Record 30 of Set 5 | thompson
# Processing Record 31 of Set 5 | cayenne
# Processing Record 32 of Set 5 | bathsheba
# Processing Record 33 of Set 5 | gort
# Processing Record 34 of Set 5 | uwayl
# City not found. Skipping...
# Processing Record 35 of Set 5 | lusaka
# Processing Record 36 of Set 5 | gannan
# Processing Record 37 of Set 5 | coihaique
# Processing Record 38 of Set 5 | sitka
# Processing Record 39 of Set 5 | goderich
# Processing Record 40 of Set 5 | flinders
# Processing Record 41 of Set 5 | erenhot
# Processing Record 42 of Set 5 | barcelos
# Processing Record 43 of Set 5 | warmbad
# Processing Record 44 of Set 5 | belen
# Processing Record 45 of Set 5 | itacare
# Processing Record 46 of Set 5 | zarubino
# Processing Record 47 of Set 5 | dibulla
# Processing Record 48 of Set 5 | maiduguri
# Processing Record 49 of Set 5 | belmonte
# Processing Record 50 of Set 5 | mabaruma
# Processing Record 1 of Set 6 | bayir
# Processing Record 2 of Set 6 | prestea
# Processing Record 3 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 6 | gisborne
# Processing Record 5 of Set 6 | kaka
# Processing Record 6 of Set 6 | ust-ilimsk
# Processing Record 7 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 6 | vardo
# Processing Record 9 of Set 6 | boralday
# Processing Record 10 of Set 6 | troitsko-pechorsk
# Processing Record 11 of Set 6 | guanambi
# Processing Record 12 of Set 6 | chandvad
# Processing Record 13 of Set 6 | brigantine
# Processing Record 14 of Set 6 | salalah
# Processing Record 15 of Set 6 | ilulissat
# Processing Record 16 of Set 6 | dmytrivka
# Processing Record 17 of Set 6 | nikolskoye
# Processing Record 18 of Set 6 | ust-omchug
# Processing Record 19 of Set 6 | eyl
# Processing Record 20 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 21 of Set 6 | banda aceh
# Processing Record 22 of Set 6 | pitimbu
# Processing Record 23 of Set 6 | mount isa
# Processing Record 24 of Set 6 | yulara
# Processing Record 25 of Set 6 | monte gordo
# Processing Record 26 of Set 6 | nusaybin
# Processing Record 27 of Set 6 | wuwei
# Processing Record 28 of Set 6 | aklavik
# Processing Record 29 of Set 6 | shihezi
# Processing Record 30 of Set 6 | amuntai
# Processing Record 31 of Set 6 | ola
# Processing Record 32 of Set 6 | sibu
# Processing Record 33 of Set 6 | nevsehir
# Processing Record 34 of Set 6 | sur
# Processing Record 35 of Set 6 | quatre cocos
# Processing Record 36 of Set 6 | poum
# Processing Record 37 of Set 6 | isangel
# Processing Record 38 of Set 6 | kamenka
# Processing Record 39 of Set 6 | viedma
# Processing Record 40 of Set 6 | kirundo
# Processing Record 41 of Set 6 | kilrush
# Processing Record 42 of Set 6 | coquimbo
# Processing Record 43 of Set 6 | banyo
# Processing Record 44 of Set 6 | severo-kurilsk
# Processing Record 45 of Set 6 | korla
# Processing Record 46 of Set 6 | nishihara
# Processing Record 47 of Set 6 | gigmoto
# Processing Record 48 of Set 6 | kaduna
# Processing Record 49 of Set 6 | trowbridge
# Processing Record 50 of Set 6 | marawi
# Processing Record 1 of Set 7 | rio gallegos
# Processing Record 2 of Set 7 | jujuy
# City not found. Skipping...
# Processing Record 3 of Set 7 | suzu
# City not found. Skipping...
# Processing Record 4 of Set 7 | high level
# Processing Record 5 of Set 7 | tondano
# Processing Record 6 of Set 7 | stephenville
# Processing Record 7 of Set 7 | belaya gora
# Processing Record 8 of Set 7 | zavetnoye
# Processing Record 9 of Set 7 | port augusta
# Processing Record 10 of Set 7 | port hedland
# Processing Record 11 of Set 7 | yerofey pavlovich
# Processing Record 12 of Set 7 | antofagasta
# Processing Record 13 of Set 7 | margate
# Processing Record 14 of Set 7 | inuvik
# Processing Record 15 of Set 7 | srednekolymsk
# Processing Record 16 of Set 7 | praia da vitoria
# Processing Record 17 of Set 7 | shchelyayur
# City not found. Skipping...
# Processing Record 18 of Set 7 | petropavl
# Processing Record 19 of Set 7 | benidorm
# Processing Record 20 of Set 7 | harper
# Processing Record 21 of Set 7 | ust-koksa
# Processing Record 22 of Set 7 | xochistlahuaca
# Processing Record 23 of Set 7 | lorengau
# Processing Record 24 of Set 7 | toora-khem
# Processing Record 25 of Set 7 | grand gaube
# Processing Record 26 of Set 7 | tomari
# Processing Record 27 of Set 7 | luga
# Processing Record 28 of Set 7 | kavieng
# Processing Record 29 of Set 7 | cherskiy
# Processing Record 30 of Set 7 | sao filipe
# Processing Record 31 of Set 7 | kisaran
# Processing Record 32 of Set 7 | trondheim
# Processing Record 33 of Set 7 | tanshui
# City not found. Skipping...
# Processing Record 34 of Set 7 | watsa
# Processing Record 35 of Set 7 | vaatsa
# City not found. Skipping...
# Processing Record 36 of Set 7 | bojnurd
# Processing Record 37 of Set 7 | gornopravdinsk
# Processing Record 38 of Set 7 | kailua
# Processing Record 39 of Set 7 | tabas
# Processing Record 40 of Set 7 | yerbogachen
# Processing Record 41 of Set 7 | pozo colorado
# Processing Record 42 of Set 7 | torrelavega
# Processing Record 43 of Set 7 | geylegphug
# City not found. Skipping...
# Processing Record 44 of Set 7 | coari
# Processing Record 45 of Set 7 | guerrero negro
# Processing Record 46 of Set 7 | souillac
# Processing Record 47 of Set 7 | dawei
# Processing Record 48 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 7 | buala
# Processing Record 50 of Set 7 | bubaque
# Processing Record 1 of Set 8 | radstadt
# Processing Record 2 of Set 8 | upata
# Processing Record 3 of Set 8 | hami
# Processing Record 4 of Set 8 | hervey bay
# Processing Record 5 of Set 8 | katangli
# Processing Record 6 of Set 8 | lakatoro
# Processing Record 7 of Set 8 | sao joao da barra
# Processing Record 8 of Set 8 | san miguel de cauri
# Processing Record 9 of Set 8 | acajutla
# Processing Record 10 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 11 of Set 8 | te anau
# Processing Record 12 of Set 8 | chapleau
# Processing Record 13 of Set 8 | richards bay
# Processing Record 14 of Set 8 | tomino
# Processing Record 15 of Set 8 | phnum penh
# City not found. Skipping...
# Processing Record 16 of Set 8 | russell
# Processing Record 17 of Set 8 | birobidzhan
# Processing Record 18 of Set 8 | la ronge
# Processing Record 19 of Set 8 | beyneu
# Processing Record 20 of Set 8 | amga
# Processing Record 21 of Set 8 | salou
# Processing Record 22 of Set 8 | padang
# Processing Record 23 of Set 8 | yatou
# Processing Record 24 of Set 8 | plotnikovo
# Processing Record 25 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 26 of Set 8 | leavenworth
# Processing Record 27 of Set 8 | porto novo
# Processing Record 28 of Set 8 | tumsar
# Processing Record 29 of Set 8 | amapa
# Processing Record 30 of Set 8 | schwabmunchen
# Processing Record 31 of Set 8 | taga
# Processing Record 32 of Set 8 | gangotri
# City not found. Skipping...
# Processing Record 33 of Set 8 | teluknaga
# Processing Record 34 of Set 8 | port elizabeth
# Processing Record 35 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 36 of Set 8 | solnechnyy
# Processing Record 37 of Set 8 | ye
# City not found. Skipping...
# Processing Record 38 of Set 8 | luoyang
# Processing Record 39 of Set 8 | le mars
# Processing Record 40 of Set 8 | nipawin
# Processing Record 41 of Set 8 | hailey
# Processing Record 42 of Set 8 | wakkanai
# Processing Record 43 of Set 8 | nerchinskiy zavod
# Processing Record 44 of Set 8 | ariquemes
# Processing Record 45 of Set 8 | moussoro
# Processing Record 46 of Set 8 | deep river
# Processing Record 47 of Set 8 | tarakan
# Processing Record 48 of Set 8 | kampot
# Processing Record 49 of Set 8 | gao
# Processing Record 50 of Set 8 | mulege
# Processing Record 1 of Set 9 | alexandria
# Processing Record 2 of Set 9 | westport
# Processing Record 3 of Set 9 | megali khora
# Processing Record 4 of Set 9 | saldanha
# Processing Record 5 of Set 9 | goure
# Processing Record 6 of Set 9 | broome
# Processing Record 7 of Set 9 | pitea
# Processing Record 8 of Set 9 | jijiang
# Processing Record 9 of Set 9 | tigil
# Processing Record 10 of Set 9 | imbituba
# Processing Record 11 of Set 9 | khandagayty
# Processing Record 12 of Set 9 | boguchar
# Processing Record 13 of Set 9 | micheweni
# Processing Record 14 of Set 9 | sorland
# Processing Record 15 of Set 9 | pankrushikha
# Processing Record 16 of Set 9 | port hueneme
# Processing Record 17 of Set 9 | nhulunbuy
# Processing Record 18 of Set 9 | santo domingo
# Processing Record 19 of Set 9 | bereda
# Processing Record 20 of Set 9 | umm lajj
# Processing Record 21 of Set 9 | pangnirtung
# Processing Record 22 of Set 9 | lompoc
# Processing Record 23 of Set 9 | sao gabriel da cachoeira
# Processing Record 24 of Set 9 | metro
# Processing Record 25 of Set 9 | jarjis
# City not found. Skipping...
# Processing Record 26 of Set 9 | bima
# Processing Record 27 of Set 9 | jumla
# Processing Record 28 of Set 9 | cullera
# Processing Record 29 of Set 9 | tuatapere
# Processing Record 30 of Set 9 | clyde river
# Processing Record 31 of Set 9 | miri
# Processing Record 32 of Set 9 | abu dhabi
# Processing Record 33 of Set 9 | batemans bay
# Processing Record 34 of Set 9 | mecca
# Processing Record 35 of Set 9 | soledade
# Processing Record 36 of Set 9 | ambon
# Processing Record 37 of Set 9 | mentakab
# Processing Record 38 of Set 9 | batagay-alyta
# Processing Record 39 of Set 9 | fomento
# Processing Record 40 of Set 9 | atar
# Processing Record 41 of Set 9 | luderitz
# Processing Record 42 of Set 9 | bandarbeyla
# Processing Record 43 of Set 9 | pabrade
# Processing Record 44 of Set 9 | flin flon
# Processing Record 45 of Set 9 | pedernales
# Processing Record 46 of Set 9 | asyut
# Processing Record 47 of Set 9 | henties bay
# Processing Record 48 of Set 9 | kruisfontein
# Processing Record 49 of Set 9 | bonthe
# Processing Record 50 of Set 9 | tukrah
# Processing Record 1 of Set 10 | hornepayne
# Processing Record 2 of Set 10 | sola
# Processing Record 3 of Set 10 | mosquera
# Processing Record 4 of Set 10 | seddon
# Processing Record 5 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 6 of Set 10 | cidreira
# Processing Record 7 of Set 10 | tautira
# Processing Record 8 of Set 10 | tombouctou
# Processing Record 9 of Set 10 | faanui
# Processing Record 10 of Set 10 | kysyl-syr
# Processing Record 11 of Set 10 | caluquembe
# Processing Record 12 of Set 10 | sesheke
# Processing Record 13 of Set 10 | mzimba
# Processing Record 14 of Set 10 | alice springs
# Processing Record 15 of Set 10 | touros
# Processing Record 16 of Set 10 | burnie
# Processing Record 17 of Set 10 | jaipur hat
# City not found. Skipping...
# Processing Record 18 of Set 10 | praya
# Processing Record 19 of Set 10 | matamoros
# Processing Record 20 of Set 10 | vavuniya
# Processing Record 21 of Set 10 | tual
# Processing Record 22 of Set 10 | pedregulho
# Processing Record 23 of Set 10 | stoyba
# City not found. Skipping...
# Processing Record 24 of Set 10 | knysna
# Processing Record 25 of Set 10 | dunedin
# Processing Record 26 of Set 10 | araguari
# Processing Record 27 of Set 10 | cairns
# Processing Record 28 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 10 | akom
# Processing Record 30 of Set 10 | port macquarie
# Processing Record 31 of Set 10 | svetlogorsk
# Processing Record 32 of Set 10 | malpe
# Processing Record 33 of Set 10 | maroantsetra
# Processing Record 34 of Set 10 | atherton
# Processing Record 35 of Set 10 | mazamari
# Processing Record 36 of Set 10 | champerico
# Processing Record 37 of Set 10 | tadine
# Processing Record 38 of Set 10 | anloga
# Processing Record 39 of Set 10 | kaeo
# Processing Record 40 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 41 of Set 10 | mackay
# Processing Record 42 of Set 10 | northam
# Processing Record 43 of Set 10 | nikolo-pavlovskoye
# Processing Record 44 of Set 10 | imeni poliny osipenko
# Processing Record 45 of Set 10 | lesnoye
# Processing Record 46 of Set 10 | oxbow
# Processing Record 47 of Set 10 | alta floresta
# Processing Record 48 of Set 10 | alekseyevskaya
# Processing Record 49 of Set 10 | pevek
# Processing Record 50 of Set 10 | vila velha
# Processing Record 1 of Set 11 | zaraza
# Processing Record 2 of Set 11 | luwuk
# Processing Record 3 of Set 11 | bolkhov
# Processing Record 4 of Set 11 | leshukonskoye
# Processing Record 5 of Set 11 | meadow lake
# Processing Record 6 of Set 11 | chagoda
# Processing Record 7 of Set 11 | rawson
# Processing Record 8 of Set 11 | iskateley
# Processing Record 9 of Set 11 | canaries
# Processing Record 10 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 11 of Set 11 | gashua
# Processing Record 12 of Set 11 | luau
# Processing Record 13 of Set 11 | mandalgovi
# Processing Record 14 of Set 11 | natchitoches
# Processing Record 15 of Set 11 | leningradskiy
# Processing Record 16 of Set 11 | svetlaya
# Processing Record 17 of Set 11 | makaha
# Processing Record 18 of Set 11 | porto tolle
# Processing Record 19 of Set 11 | okha
# Processing Record 20 of Set 11 | salinopolis
# Processing Record 21 of Set 11 | asadabad
# Processing Record 22 of Set 11 | drayton valley
# Processing Record 23 of Set 11 | port-de-paix
# City not found. Skipping...
# Processing Record 24 of Set 11 | tonj
# Processing Record 25 of Set 11 | hearst
# Processing Record 26 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 27 of Set 11 | mangai
# Processing Record 28 of Set 11 | naryan-mar
# Processing Record 29 of Set 11 | manzil tamim
# City not found. Skipping...
# Processing Record 30 of Set 11 | kupang
# Processing Record 31 of Set 11 | cervo
# Processing Record 32 of Set 11 | palana
# Processing Record 33 of Set 11 | sumbe
# Processing Record 34 of Set 11 | xadani
# City not found. Skipping...
# Processing Record 35 of Set 11 | la libertad
# Processing Record 36 of Set 11 | mayo
# Processing Record 37 of Set 11 | waipawa
# Processing Record 38 of Set 11 | uren
# Processing Record 39 of Set 11 | misratah
# Processing Record 40 of Set 11 | ituiutaba
# Processing Record 41 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 11 | santa vitoria
# Processing Record 43 of Set 11 | tshikapa
# Processing Record 44 of Set 11 | waharoa
# Processing Record 45 of Set 11 | valparaiso
# Processing Record 46 of Set 11 | baglan
# Processing Record 47 of Set 11 | oskarshamn
# Processing Record 48 of Set 11 | masaka
# Processing Record 49 of Set 11 | kabanjahe
# Processing Record 50 of Set 11 | druzhba
# Processing Record 1 of Set 12 | deer lake
# Processing Record 2 of Set 12 | harnosand
# Processing Record 3 of Set 12 | kibre mengist
# Processing Record 4 of Set 12 | innisfail
# Processing Record 5 of Set 12 | labuhan
# Processing Record 6 of Set 12 | mahibadhoo
# Processing Record 7 of Set 12 | asau
# Processing Record 8 of Set 12 | veraval
# Processing Record 9 of Set 12 | angoche
# Processing Record 10 of Set 12 | lithakia
# Processing Record 11 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 12 of Set 12 | sorsk
# Processing Record 13 of Set 12 | meulaboh
# Processing Record 14 of Set 12 | bosaso
# Processing Record 15 of Set 12 | soure
# Processing Record 16 of Set 12 | beringovskiy
# Processing Record 17 of Set 12 | muret
# Processing Record 18 of Set 12 | neumunster
# Processing Record 19 of Set 12 | tuy hoa
# Processing Record 20 of Set 12 | joao pinheiro
# Processing Record 21 of Set 12 | deputatskiy
# Processing Record 22 of Set 12 | ixtapa
# Processing Record 23 of Set 12 | qaqortoq
# Processing Record 24 of Set 12 | pouembout
# Processing Record 25 of Set 12 | rabaul
# Processing Record 26 of Set 12 | saint anthony
# Processing Record 27 of Set 12 | tura
# Processing Record 28 of Set 12 | blackwater
# Processing Record 29 of Set 12 | mitu
# Processing Record 30 of Set 12 | urengoy
# Processing Record 31 of Set 12 | varhaug
# Processing Record 32 of Set 12 | ponferrada
# Processing Record 33 of Set 12 | petatlan
# Processing Record 34 of Set 12 | kendari
# Processing Record 35 of Set 12 | minab
# Processing Record 36 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 37 of Set 12 | ayios vasilios
# Processing Record 38 of Set 12 | polis
# Processing Record 39 of Set 12 | port lincoln
# Processing Record 40 of Set 12 | severo-yeniseyskiy
# Processing Record 41 of Set 12 | kandrian
# Processing Record 42 of Set 12 | morehead
# Processing Record 43 of Set 12 | mehamn
# Processing Record 44 of Set 12 | san luis
# Processing Record 45 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 12 | narsaq
# Processing Record 47 of Set 12 | portland
# Processing Record 48 of Set 12 | praia
# Processing Record 49 of Set 12 | atakpame
# Processing Record 50 of Set 12 | myanaung
# Processing Record 1 of Set 13 | ulaangom
# Processing Record 2 of Set 13 | red wing
# Processing Record 3 of Set 13 | manzil jamil
# City not found. Skipping...
# Processing Record 4 of Set 13 | gagra
# Processing Record 5 of Set 13 | najran
# Processing Record 6 of Set 13 | manzhouli
# Processing Record 7 of Set 13 | cocobeach
# Processing Record 8 of Set 13 | svay rieng
# Processing Record 9 of Set 13 | sivas
# Processing Record 10 of Set 13 | kardla
# Processing Record 11 of Set 13 | makasar
# Processing Record 12 of Set 13 | japura
# Processing Record 13 of Set 13 | pemangkat
# Processing Record 14 of Set 13 | zdvinsk
# Processing Record 15 of Set 13 | matagami
# Processing Record 16 of Set 13 | loreto
# Processing Record 17 of Set 13 | kidal
# Processing Record 18 of Set 13 | shaunavon
# Processing Record 19 of Set 13 | along
# Processing Record 20 of Set 13 | pyu
# Processing Record 21 of Set 13 | ahipara
# Processing Record 22 of Set 13 | tolaga bay
# Processing Record 23 of Set 13 | vostok
# Processing Record 24 of Set 13 | olafsvik
# Processing Record 25 of Set 13 | charters towers
# Processing Record 26 of Set 13 | san cristobal
# Processing Record 27 of Set 13 | kuala terengganu
# Processing Record 28 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 29 of Set 13 | awash
# Processing Record 30 of Set 13 | moranbah
# Processing Record 31 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 32 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 33 of Set 13 | susaki
# Processing Record 34 of Set 13 | tyrma
# Processing Record 35 of Set 13 | bossembele
# City not found. Skipping...
# Processing Record 36 of Set 13 | cabedelo
# Processing Record 37 of Set 13 | kabare
# Processing Record 38 of Set 13 | umm kaddadah
# Processing Record 39 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 40 of Set 13 | davila
# Processing Record 41 of Set 13 | nuuk
# Processing Record 42 of Set 13 | grenada
# Processing Record 43 of Set 13 | dien bien
# City not found. Skipping...
# Processing Record 44 of Set 13 | belogorsk
# Processing Record 45 of Set 13 | thinadhoo
# Processing Record 46 of Set 13 | brae
# Processing Record 47 of Set 13 | ayagoz
# Processing Record 48 of Set 13 | kaya
# Processing Record 49 of Set 13 | hovd
# Processing Record 50 of Set 13 | mumford
# Processing Record 1 of Set 14 | soe
# Processing Record 2 of Set 14 | bay city
# Processing Record 3 of Set 14 | mountain home
# Processing Record 4 of Set 14 | abu samrah
# Processing Record 5 of Set 14 | moron
# Processing Record 6 of Set 14 | anupgarh
# Processing Record 7 of Set 14 | pioner
# Processing Record 8 of Set 14 | srandakan
# Processing Record 9 of Set 14 | palencia
# Processing Record 10 of Set 14 | saint-denis
# Processing Record 11 of Set 14 | carauari
# Processing Record 12 of Set 14 | calvia
# Processing Record 13 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 15 of Set 14 | scottsburgh
# City not found. Skipping...
# Processing Record 16 of Set 14 | dingle
# Processing Record 17 of Set 14 | presidencia roque saenz pena
# Processing Record 18 of Set 14 | gandu
# Processing Record 19 of Set 14 | shimoda
# Processing Record 20 of Set 14 | rurrenabaque
# Processing Record 21 of Set 14 | visnes
# Processing Record 22 of Set 14 | burns lake
# Processing Record 23 of Set 14 | tiznit
# Processing Record 24 of Set 14 | ugoofaaru
# Processing Record 25 of Set 14 | kieta
# Processing Record 26 of Set 14 | tecolutla
# Processing Record 27 of Set 14 | tooele
# Processing Record 28 of Set 14 | zabaykalsk
# Processing Record 29 of Set 14 | wenling
# Processing Record 30 of Set 14 | ginda
# Processing Record 31 of Set 14 | bestobe
# Processing Record 32 of Set 14 | tanete
# Processing Record 33 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 14 | amot
# Processing Record 35 of Set 14 | lata
# Processing Record 36 of Set 14 | newport
# Processing Record 37 of Set 14 | bukachacha
# Processing Record 38 of Set 14 | ucluelet
# Processing Record 39 of Set 14 | cacu
# Processing Record 40 of Set 14 | le vauclin
# Processing Record 41 of Set 14 | buraydah
# Processing Record 42 of Set 14 | auki
# Processing Record 43 of Set 14 | coos bay
# Processing Record 44 of Set 14 | perry
# Processing Record 45 of Set 14 | darhan
# Processing Record 46 of Set 14 | axim
# Processing Record 47 of Set 14 | karratha
# Processing Record 48 of Set 14 | samarai
# Processing Record 49 of Set 14 | miraflores
# Processing Record 50 of Set 14 | jahrom
# City not found. Skipping...
# Processing Record 1 of Set 15 | nizhneudinsk
# Processing Record 2 of Set 15 | timizart
# Processing Record 3 of Set 15 | lerwick
# Processing Record 4 of Set 15 | pokhara
# Processing Record 5 of Set 15 | gilbues
# Processing Record 6 of Set 15 | umm durman
# City not found. Skipping...
# Processing Record 7 of Set 15 | chhuikhadan
# Processing Record 8 of Set 15 | condoto
# Processing Record 9 of Set 15 | nueva guinea
# Processing Record 10 of Set 15 | ourinhos
# Processing Record 11 of Set 15 | son la
# Processing Record 12 of Set 15 | pasaco
# Processing Record 13 of Set 15 | mahajanga
# Processing Record 14 of Set 15 | pimentel
# Processing Record 15 of Set 15 | kitimat
# Processing Record 16 of Set 15 | panjab
# Processing Record 17 of Set 15 | kibakwe
# Processing Record 18 of Set 15 | laguna
# Processing Record 19 of Set 15 | chernushka
# Processing Record 20 of Set 15 | port moresby
# Processing Record 21 of Set 15 | ilhabela
# Processing Record 22 of Set 15 | taltal
# Processing Record 23 of Set 15 | soto la marina
# Processing Record 24 of Set 15 | willmar
# Processing Record 25 of Set 15 | eresos
# Processing Record 26 of Set 15 | komsomolskiy
# Processing Record 27 of Set 15 | hambantota
# Processing Record 28 of Set 15 | kalengwa
# Processing Record 29 of Set 15 | arman
# Processing Record 30 of Set 15 | bilma
# Processing Record 31 of Set 15 | porosozero
# Processing Record 32 of Set 15 | pueblo
# Processing Record 33 of Set 15 | lincoln
# Processing Record 34 of Set 15 | hay river
# Processing Record 35 of Set 15 | aykhal
# Processing Record 36 of Set 15 | norden
# Processing Record 37 of Set 15 | bafia
# Processing Record 38 of Set 15 | damghan
# Processing Record 39 of Set 15 | isparta
# Processing Record 40 of Set 15 | daru
# Processing Record 41 of Set 15 | nizhniy baskunchak
# Processing Record 42 of Set 15 | giporlos
# Processing Record 43 of Set 15 | seoul
# Processing Record 44 of Set 15 | bocaranga
# City not found. Skipping...
# Processing Record 45 of Set 15 | banjarmasin
# Processing Record 46 of Set 15 | dongsheng
# Processing Record 47 of Set 15 | port-cartier
# Processing Record 48 of Set 15 | kirovohrad
# Processing Record 49 of Set 15 | havre-saint-pierre
# Processing Record 50 of Set 15 | bandarban
# Processing Record 1 of Set 16 | carballo
# Processing Record 2 of Set 16 | paamiut
# Processing Record 3 of Set 16 | surt
# Processing Record 4 of Set 16 | chernyshevskiy
# Processing Record 5 of Set 16 | oranjestad
# Processing Record 6 of Set 16 | soyo
# Processing Record 7 of Set 16 | nouadhibou
# Processing Record 8 of Set 16 | gazojak
# Processing Record 9 of Set 16 | naze
# Processing Record 10 of Set 16 | bombay
# Processing Record 11 of Set 16 | matara
# Processing Record 12 of Set 16 | cap-aux-meules
# ----------------------------
# Data Retrieval Complete
# ----------------------------

# %%
city_weather
# Out:
# {'coord': {'lon': -61.8597, 'lat': 47.3821},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03n'}],
#  'base': 'stations',
#  'main': {'temp': 62.62,
#   'feels_like': 63,
#   'temp_min': 62.62,
#   'temp_max': 62.62,
#   'pressure': 1016,
#   'humidity': 94},
#  'visibility': 10000,
#  'wind': {'speed': 10.36, 'deg': 330},
#  'clouds': {'all': 48},
#  'dt': 1656647230,
#  'sys': {'type': 1,
#   'id': 274,
#   'country': 'CA',
#   'sunrise': 1656663277,
#   'sunset': 1656720461},
#  'timezone': -10800,
#  'id': 5915327,
#  'name': 'Cap-aux-Meules',
#  'cod': 200}

# %%
city_data_df = pd.DataFrame(city_data)

city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Merauke      ID  -8.4667  140.3333     80.85        84          34
# 1      Muscat      OM  23.6139   58.5922     91.42        66         100
# 2      Dalvik      IS  65.9702  -18.5286     46.33        93          84
# 3        Hilo      US  19.7297 -155.0900     82.13        77          40
# 4     Hajipur      IN  25.6833   85.2167     84.18        94          75
# 5      Atuona      PF  -9.8000 -139.0333     76.71        69           3
# 6        Sapa      PH   5.1544  120.3241     85.93        70          58
# 7      Hobart      AU -42.8794  147.3294     54.27        68          20
# 8        Lebu      CL -37.6167  -73.6500     51.96        86          74
# 9  Port Blair      IN  11.6667   92.7500     86.04        79          75
#
#    Wind Speed Current Description
# 0       12.24          light rain
# 1        3.11     overcast clouds
# 2        2.55       broken clouds
# 3        0.00    scattered clouds
# 4        3.44                mist
# 5       11.16           clear sky
# 6       10.22          light rain
# 7       10.36          few clouds
# 8       23.47          light rain
# 9        5.75       broken clouds

# %%
# create the output file

output_data_file = 'weather_database/weather_py_database.csv'

# export the city_data into a csv

city_data_df.to_csv(output_data_file)
